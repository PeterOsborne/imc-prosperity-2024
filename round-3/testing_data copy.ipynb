# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd
import jsonpickle

# %%
file_path = 'data/prices_round_3_day_1.csv'
data = pd.read_csv(file_path, encoding='cp1252', delimiter=';')

# %%
import os
file_path1 = 'testdata/GIFT_BASKET_history.txt'
file_path2 = 'testdata/CHOCOLATE_history.txt'

with open(file_path2, 'r') as f:
    choc = pd.read_json(f.read()).set_index('timestamp')

with open(file_path1, 'r') as f:
    gift = pd.read_json(f.read()).set_index('timestamp')

# %%
plt.figure(figsize=(10, 6))
plt.plot(gift)
plt.plot(roses*6 + 23000)

# %%
type(len(a))
# Out:
# int

# %%
# Out:
#            mid_price
# timestamp
# 682500        7994.0
# 683000        7992.0
# 683500        7987.5
# 684000        7987.5
# 684500        7987.0
# ...              ...
# 755500        8057.5
# 756000        8055.0
# 756500        8053.5
# 757000        8051.0
# 757500        8043.5
#
# [151 rows x 1 columns]

# %%
choc
# Out:
#            mid_price
# timestamp
# 682000       71345.5
# 682500       71323.5
# 683000       71292.5
# 683500       71266.5
# 684000       71251.5
# ...              ...
# 755000       71249.5
# 755500       71235.5
# 756000       71251.5
# 756500       71272.5
# 757000       71246.0
#
# [151 rows x 1 columns]

# %%
gift/choc
# Out:
#            mid_price
# timestamp
# 682000           NaN
# 682500      0.112081
# 683000      0.112102
# 683500      0.112079
# 684000      0.112103
# ...              ...
# 755500      0.113111
# 756000      0.113050
# 756500      0.112996
# 757000      0.113003
# 757500           NaN
#
# [152 rows x 1 columns]
